# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime, timedelta
import great_expectations as gx
import sys
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 5>()
#       3 from sqlalchemy import create_engine
#       4 from datetime import datetime, timedelta
# ----> 5 import great_expectations as gx
#       6 import sys
#
# File /opt/anaconda3/lib/python3.9/site-packages/great_expectations/__init__.py:10, in <module>
#       7 del _get_versions
#       9 # great_expectations.data_context must be imported first or we will have circular dependency issues
# ---> 10 import great_expectations.data_context  # isort:skip
#      11 import great_expectations.core
#      13 from great_expectations.data_context.data_context.context_factory import get_context
#
# File /opt/anaconda3/lib/python3.9/site-packages/great_expectations/data_context/__init__.py:1, in <module>
# ----> 1 from great_expectations.data_context.data_context import (
#       2     AbstractDataContext,
#       3     CloudDataContext,
#       4     EphemeralDataContext,
#       5     FileDataContext,
#       6     get_context,
#       7     project_manager,
#       8     set_context,
#       9 )
#
# File /opt/anaconda3/lib/python3.9/site-packages/great_expectations/data_context/data_context/__init__.py:1, in <module>
# ----> 1 from great_expectations.data_context.data_context.abstract_data_context import (
#       2     AbstractDataContext,
#       3 )
#       4 from great_expectations.data_context.data_context.cloud_data_context import (
#       5     CloudDataContext,
#       6 )
#       7 from great_expectations.data_context.data_context.context_factory import (
#       8     get_context,
#       9     project_manager,
#      10     set_context,
#      11 )
#
# File /opt/anaconda3/lib/python3.9/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:37, in <module>
#      30 import great_expectations.exceptions as gx_exceptions
#      31 from great_expectations._docs_decorators import (
#      32     deprecated_method_or_class,
#      33     new_argument,
#      34     new_method_or_class,
#      35     public_api,
#      36 )
# ---> 37 from great_expectations.analytics.client import init as init_analytics
#      38 from great_expectations.analytics.client import submit as submit_event
#      39 from great_expectations.analytics.config import ENV_CONFIG
#
# File /opt/anaconda3/lib/python3.9/site-packages/great_expectations/analytics/__init__.py:1, in <module>
# ----> 1 from great_expectations.analytics.client import init, submit
#
# File /opt/anaconda3/lib/python3.9/site-packages/great_expectations/analytics/client.py:9, in <module>
#       5 from uuid import UUID
#       7 import posthog
# ----> 9 from great_expectations.analytics.config import ENV_CONFIG, Config, update_config
#      11 if TYPE_CHECKING:
#      12     from great_expectations.analytics.base_event import Event
#
# File /opt/anaconda3/lib/python3.9/site-packages/great_expectations/analytics/config.py:6, in <module>
#       3 from typing import Optional
#       4 from uuid import UUID
# ----> 6 from great_expectations.compatibility.pydantic import (
#       7     BaseSettings,
#       8     GenericModel,
#       9     HttpUrl,
#      10 )
#      13 class _EnvConfig(BaseSettings):
#      14     gx_analytics_enabled: Optional[bool] = None
#
# File /opt/anaconda3/lib/python3.9/site-packages/great_expectations/compatibility/pydantic.py:11, in <module>
#       5 from great_expectations.compatibility.not_imported import (
#       6     is_version_greater_or_equal,
#       7 )
#       9 if is_version_greater_or_equal(version=pydantic.VERSION, compare_version="2.0.0"):
#      10     # TODO: don't use star imports
# ---> 11     from pydantic.v1 import *  # noqa: F403 # FIXME CoP
#      12     from pydantic.v1 import (
#      13         AnyUrl,
#      14         BaseSettings,
#    (...)
#      25         typing,
#      26     )
#      27     from pydantic.v1.generics import GenericModel
#
# File /opt/anaconda3/lib/python3.9/site-packages/pydantic/v1/__init__.py:2, in <module>
#       1 # flake8: noqa
# ----> 2 from . import dataclasses
#       3 from .annotated_types import create_model_from_namedtuple, create_model_from_typeddict
#       4 from .class_validators import root_validator, validator
#
# File /opt/anaconda3/lib/python3.9/site-packages/pydantic/v1/dataclasses.py:55, in <module>
#      53 from .errors import DataclassTypeError
#      54 from .fields import Field, FieldInfo, Required, Undefined
# ---> 55 from .main import create_model, validate_model
#      56 from .utils import ClassAttribute
#      58 if TYPE_CHECKING:
#
# File /opt/anaconda3/lib/python3.9/site-packages/pydantic/v1/main.py:120, in <module>
#     113 # Note `ModelMetaclass` refers to `BaseModel`, but is also used to *create* `BaseModel`, so we need to add this extra
#     114 # (somewhat hacky) boolean to keep track of whether we've created the `BaseModel` class yet, and therefore whether it's
#     115 # safe to refer to it. If it *hasn't* been created, we assume that the `__new__` call we're in the middle of is for
#     116 # the `BaseModel` class, since that's defined immediately after the metaclass.
#     117 _is_base_model_class_defined = False
# --> 120 @dataclass_transform(kw_only_default=True, field_specifiers=(Field,))
#     121 class ModelMetaclass(ABCMeta):
#     122     @no_type_check  # noqa C901
#     123     def __new__(mcs, name, bases, namespace, **kwargs):  # noqa C901
#     124         fields: Dict[str, ModelField] = {}
#
# TypeError: dataclass_transform() got an unexpected keyword argument 'field_specifiers'
